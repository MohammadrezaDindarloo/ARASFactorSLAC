# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import csv
import os
direc = os.getcwd()

# %% [markdown]
# # Result

# %%
cutoff = 50

# %% [markdown]
# ### result for uwb

# %%
rows = []
with open(direc + "/Dataset150_v1/simuation_uwb_result.csv", 'r') as file:
    csvreader = csv.reader(file)
    header = next(csvreader)
    rows.append(header)
    for row in csvreader:
        if float(row[4]) < cutoff:
            rows.append(row)
error_pulley_sim_uwb = [float(row[0]) for row in rows]
error_pulley_sim_uwb = [float(row[1]) for row in rows]
error_pulley_sim_uwb = [float(row[2]) for row in rows]
error_pulley_sim_uwb = [float(row[3]) for row in rows]
error_pulley_sim_sum_uwb = [float(row[4]) for row in rows]
plt.hist(error_pulley_sim_sum_uwb)
plt.show()

# %%
rows = []
with open(direc + "/Dataset150_v1/realdata_uwb_result.csv", 'r') as file:
    csvreader = csv.reader(file)
    header = next(csvreader)
    rows.append(header)
    for row in csvreader:
        if float(row[4]) < cutoff:
            rows.append(row)
error_pulley_real_uwb = [float(row[0]) for row in rows]
error_pulley_real_uwb = [float(row[1]) for row in rows]
error_pulley_real_uwb = [float(row[2]) for row in rows]
error_pulley_real_uwb = [float(row[3]) for row in rows]
error_pulley_real_sum_uwb = [float(row[4]) for row in rows]
plt.hist(error_pulley_real_sum_uwb)
plt.show()

# %% [markdown]
# ### result for encoder

# %%
rows = []
with open(direc + "/Dataset150_v1/simuation_enc_result.csv", 'r') as file:
    csvreader = csv.reader(file)
    header = next(csvreader)
    rows.append(header)
    for row in csvreader:
        if float(row[4]) < cutoff:
            rows.append(row)
error_pulley_sim_enc= [float(row[0]) for row in rows]
error_pulley_sim_enc = [float(row[1]) for row in rows]
error_pulley_sim_enc = [float(row[2]) for row in rows]
error_pulley_sim_enc = [float(row[3]) for row in rows]
error_pulley_sim_sum_enc = [float(row[4]) for row in rows]
plt.hist(error_pulley_sim_enc)
plt.show()

# %%
rows = []
with open(direc + "/Dataset150_v1/realdata_enc_result.csv", 'r') as file:
    csvreader = csv.reader(file)
    header = next(csvreader)
    rows.append(header)
    for row in csvreader:
        if float(row[4]) < cutoff:
            rows.append(row)
error_pulley_real_enc= [float(row[0]) for row in rows]
error_pulley_real_enc = [float(row[1]) for row in rows]
error_pulley_real_enc = [float(row[2]) for row in rows]
error_pulley_real_enc = [float(row[3]) for row in rows]
error_pulley_real_sum_enc = [float(row[4]) for row in rows]
plt.hist(error_pulley_real_enc)
plt.show()

# %% [markdown]
# ### result for encoder + uwb

# %%
rows = []
with open(direc + "/Dataset150_v1/simuation_enc_uwb_result.csv", 'r') as file:
    csvreader = csv.reader(file)
    header = next(csvreader)
    rows.append(header)
    for row in csvreader:
        if float(row[4]) < cutoff:
            rows.append(row)
error_pulley_sim_enc_uwb= [float(row[0]) for row in rows]
error_pulley_sim_enc_uwb = [float(row[1]) for row in rows]
error_pulley_sim_enc_uwb = [float(row[2]) for row in rows]
error_pulley_sim_enc_uwb = [float(row[3]) for row in rows]
error_pulley_sim_sum_enc_uwb = [float(row[4]) for row in rows]
plt.hist(error_pulley_sim_enc_uwb)
plt.show()

# %%
rows = []
with open(direc + "/Dataset150_v1/realdata_enc_uwb_result.csv", 'r') as file:
    csvreader = csv.reader(file)
    header = next(csvreader)
    rows.append(header)
    for row in csvreader:
        if float(row[4]) < cutoff:
            rows.append(row)
error_pulley_real_enc_uwb= [float(row[0]) for row in rows]
error_pulley_real_enc_uwb = [float(row[1]) for row in rows]
error_pulley_real_enc_uwb = [float(row[2]) for row in rows]
error_pulley_real_enc_uwb = [float(row[3]) for row in rows]
error_pulley_real_sum_enc_uwb = [float(row[4]) for row in rows]
plt.hist(error_pulley_real_enc_uwb)
plt.show()

# %%
data = [error_pulley_sim_sum_uwb, error_pulley_sim_sum_enc, error_pulley_sim_sum_enc_uwb]
labels = ["uwb", "enc", "enc_uwb"]
plt.boxplot(data, labels=labels)
plt.title('SUM OF ERRORs')
plt.show()

# %%
data = [error_pulley_real_sum_uwb, error_pulley_real_sum_enc, error_pulley_real_sum_enc_uwb]
labels = ["uwb", "enc", "enc_uwb"]
plt.boxplot(data, labels=labels)
plt.title('SUM OF ERRORs')
plt.show()
